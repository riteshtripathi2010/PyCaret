# %%
import pandas as pd
import numpy as np
df= pd.read_csv("/Users/riteshtripathi/Desktop/Data School/Data From Youtube/Krish/creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
len(df[df['Class']==0])
# Out:
# 284315

# %%
from pycaret.classification import *
clf1 = setup(data = df, target = 'Class')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_bca44556_bf57_11ea_b59c_8c8590257adb" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bca44556_bf57_11ea_b59c_8c8590257adblevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_bca44556_bf57_11ea_b59c_8c8590257adbrow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_bca44556_bf57_11ea_b59c_8c8590257adbrow0_col1" class="data row0 col1" >540</td>
#             </tr>
#             <tr>
#                         <th id="T_bca44556_bf57_11ea_b59c_8c8590257adblevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_bca44556_bf57_11ea_b59c_8c8590257adbrow1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
compare_models()
#Pycaret is good for handling imbalance data set
#here output is imbalanced, and for imbalanced we dont check accuracy
#hence we check f1 and kappa
# Out:
# <style  type="text/css" >
#     #T_ddbd9ff2_bf5d_11ea_b59c_8c8590257adb th {
#           text-align: left;
#     }    #T_ddbd9ff2_bf5d_11ea_b59c_8c8590257adbrow0_col0 {
#             text-align:  left;
#         }    #T_ddbd9ff2_bf5d_11ea_b59c_8c8590257adbrow0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_ddbd9ff2_bf5d_11ea_b59c_8c8590257adbrow0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_ddbd9ff2_bf5d_11ea_b59c_8c8590257adbrow0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_ddbd9ff2_bf5d_11ea_b59c_8c8590257adbrow0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_ddbd9ff2_bf5d_11ea_b59c_8c8590257adbrow0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_ddbd9ff2_bf5d_11ea_b59c_8c8590257adbrow0_col6 {
#             background-color:  yellow;
#             text-align:  left;
# ...

# %%
# creating CatBoost Classifier 
catBoost = create_model('catboost')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9994  0.9467  0.6667  0.9412  0.7805  0.7802
# 1       0.9997  0.9900  0.8333  1.0000  0.9091  0.9089
# 2       0.9994  0.9633  0.7500  0.9000  0.8182  0.8179
# 3       0.9994  0.9626  0.7200  0.9474  0.8182  0.8179
# 4       0.9995  0.9421  0.7917  0.9048  0.8444  0.8442
# 5       0.9995  0.9940  0.7083  1.0000  0.8293  0.8290
# 6       0.9995  0.9875  0.7083  1.0000  0.8293  0.8290
# 7       0.9992  0.9511  0.6250  0.8824  0.7317  0.7313
# 8       0.9994  0.9823  0.7083  0.9444  0.8095  0.8092
# 9       0.9996  0.9846  0.7917  1.0000  0.8837  0.8835
# Mean    0.9995  0.9704  0.7303  0.9520  0.8254  0.8251
# SD      0.0001  0.0185  0.0594  0.0438  0.0469  0.0469

# %%
catBoost

# %%
model = tune_model('catBoost')
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: (Value Error): Estimator Not Available. Please see docstring for list of available estimators.
